# %% [markdown]
# # Install Required Libraries
# Install necessary packages such as markdown and weasyprint for PDF conversion.

# %%
# !pip install pypandoc
# Out:
# ...
# WARNING: Ignoring invalid distribution ~bt-core (C:\Users\ASUS\miniconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~bt-core (C:\Users\ASUS\miniconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~bt-core (C:\Users\ASUS\miniconda3\Lib\site-packages)

# %% [markdown]
# # Load the Markdown File
# Use Python code to load the Markdown report file.

# %%
import pypandoc

# Convert Markdown to PDF directly
pypandoc.convert_file('bao-cao-thong-ke-thu-thap-du-lieu.md', 'pdf', outputfile='bao-cao-thong-ke-thu-thap-du-lieu.pdf')

# %% [markdown]
# # Convert to PDF
# Execute the conversion process to generate a PDF output.

# %%
print("PDF generated successfully!")

# %% [markdown]
# # Handle Conversion Options
# Customize the conversion with options like output path.

# %%
# Example with custom output path
output_path = 'reports/bao-cao-thong-ke-thu-thap-du-lieu.pdf'
HTML(string=html_content).write_pdf(output_path)

print(f"PDF saved to {output_path}")
